# %% [markdown]
# ### Houses Price Prediction Model
#
# Dataset used: Boston houses in sklearn datasets.
#
# Contributed by Aryan Pareek ☺
#
# Github [diffrxction](https://github.com/diffrxction)

# %% [markdown]
# # Objective
# Create a machine learning model using linear regression and Boston housing dataset while following the machine learning workflow.

# %% [markdown]
# # Project Context
# In machine learning we often write computer programs which automatically improve with experience which are termed as machine learning models. It saves us from explicitly writing code for complex real world data.
#
# In this project we will use supervised learning (a branch of machine learning where we teach our model with well-labelled data). Here we first explore different attributes of Boston housing dataset then a portion of the dataset will be used to train the linear regression model after which we use the trained model to get predictions on the validation paortion of the dataset.

# %% [markdown]
# # Approach

# %% [markdown]
# * Exploring and analyzing the data used for making prediction.
# * Creating a simple model using linear regression.
# * Using the model to carryout prediction and evaluating it's efficiency.

# %% [markdown]
# # Importing libraries and dataset
#
# In this section we will load in a few libraries which are needed to analyse, visualize, train, validate and test our model.
#
# We will be loading our dataset from sklearn.

# %% [markdown]
# This dataset contains information collected by the U.S Census Service concerning housing in the area of Boston MA As mentioned about The Boston Housing Dataset. There are 14 attributes in each case of the dataset
# ```
# CRIM - per capita crime rate by town
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS - proportion of non-retail business acres per town.
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# NOX - nitric oxides concentration (parts per 10 million)
# RM - average number of rooms per dwelling
# AGE - proportion of owner-occupied units built prior to 1940
# DIS - weighted distances to five Boston employment centres
# RAD - index of accessibility to radial highways
# TAX - full-value property-tax rate per $10,000
# PTRATIO - pupil-teacher ratio by town
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# LSTAT - % lower status of the population
# MEDV - Median value of owner-occupied homes in $1000's
# ```
# Our goal is to select the variables which predict the best MEDV possible, and also to suggest a machine learning model to predict MEDV.

# %% [markdown]
# # Requirements
#
# Import the stated libraries:
#
# - Numpy
#
# - Pandas
#
# - Sklearn
#
# - matplotlib.plt
#
# - Seaborn
#
# Import Boston housing dataset from Sklearn.

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline
plt.style.use(['dark_background']) #Dark background is just cooler imo.

# %%
from sklearn.datasets import load_boston
var = load_boston()
#var holds the boston dataset

# %% [markdown]
# # Data exploration and preprocessing
#
# In this section we will analyse our dataset using different methods before creating a dataframe.
#
# Analysis is the key to developing the most efficient model as per the data's requirement.
#
# Then we will also carry out preprocessing on the dataframe for using the linear regression model.

# %%
df = pd.DataFrame(var.data, columns=var.feature_names) 
#df is loaded in as the dataframe because dataframes tabulate the data making them more readable,

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %% [markdown]
# ### Assigned Tasks
#
# 1. Use functions head() and tail() to see first and last five rows of the created dataframe.
#
# 2. Use describe() to get even further insights on the created data frame.
#
# 3. Add another column to the dataframe and store the value of target attribute in it `df['MEDV'] = var.target` Confirm the addition of column using `head()`.
#
# 4. Use df.dtype or df.info to know data type various features present in the dataset. If we find categorical data, then we'll require to use different encoding methods.
#
# 5. Use `df.isnull().sum()` to check for missing values in each column. If we find missing values, then either we will place values there or we can drop the row or column.
#
# 6. Create a heatmap using seaborn to find corelation between different features and labels. In model creation we will be using features having a high corelation with our target label.
#
# 7. Create KDE plot of different variables using seaborn library.

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df['MEDV'] = var.target

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.info()
#We can also use df.dtype()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# As per the above observation we have checked the count, mean, percentile(etc.)
#
# Now if we will analyze the data, the ZN column has 0 values in 25% - 50% and it is skewed its gaining results at 75% and above.
#
# As ZN is proportion to the residential land zoned for lots over 25,000 sq.ft, we can conclude that it is conditional data.
#
# CHAS column has 0 values in 25%, 50%, 75%.
# As CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise) and it is a categorized data (0,1).
#
# So we have concluded that both ZN & Chas columns are skewed and can impact MEDV so we have to remove ZN & Chas.

# %%
df = df.drop(["ZN", "CHAS"], axis = 1)
df.describe()
# Out:
#              CRIM       INDUS         NOX          RM         AGE         DIS  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.136779    0.554695    6.284634   68.574901    3.795043
# std      8.601545    6.860353    0.115878    0.702617   28.148861    2.105710
# min      0.006320    0.460000    0.385000    3.561000    2.900000    1.129600
# 25%      0.082045    5.190000    0.449000    5.885500   45.025000    2.100175
# 50%      0.256510    9.690000    0.538000    6.208500   77.500000    3.207450
# 75%      3.677083   18.100000    0.624000    6.623500   94.075000    5.188425
# max     88.976200   27.740000    0.871000    8.780000  100.000000   12.126500
#
#               RAD         TAX     PTRATIO           B       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     9.549407  408.237154   18.455534  356.674032   12.653063   22.532806
# ...

# %%
df.columns
# Out:
# Index(['CRIM', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO',
#        'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df.shape
# Out:
# (506, 12)

# %%
#lets make the correlation matrix
corr_data = df.corr()
corr_data.style.background_gradient(cmap="magma")
# Out:
# <style  type="text/css" >
# #T_708a3_row0_col0,#T_708a3_row1_col1,#T_708a3_row2_col2,#T_708a3_row3_col3,#T_708a3_row4_col4,#T_708a3_row5_col5,#T_708a3_row6_col6,#T_708a3_row7_col7,#T_708a3_row8_col8,#T_708a3_row9_col9,#T_708a3_row10_col10,#T_708a3_row11_col11{
#             background-color:  #fcfdbf;
#             color:  #000000;
#         }#T_708a3_row0_col1{
#             background-color:  #ee5b5e;
#             color:  #000000;
#         }#T_708a3_row0_col2{
#             background-color:  #f2645c;
#             color:  #000000;
#         }#T_708a3_row0_col3{
#             background-color:  #4e117b;
#             color:  #f1f1f1;
#         }#T_708a3_row0_col4{
#             background-color:  #e85362;
#             color:  #000000;
#         }#T_708a3_row0_col5,#T_708a3_row9_col2,#T_708a3_row9_col8{
#             background-color:  #440f76;
#             color:  #f1f1f1;
#         }#T_708a3_row0_col6{
#             background-color:  #fb8761;
#             color:  #000000;
# ...

# %%
#From the above correlation matrix we can see that Tax & RAD are highly correlated,
#From the observation of data, RAD is a more impactful variable in predicting the Medv so we remove Tax.

df = df.drop(["TAX"], axis = 1)
df.shape
# Out:
# (506, 11)

# %%
#On making the correlation matrix again, we get
corr_data = df.corr()
corr_data.style.background_gradient(cmap='RdBu')
# Out:
# <style  type="text/css" >
# #T_609a9_row0_col0,#T_609a9_row1_col1,#T_609a9_row2_col2,#T_609a9_row3_col3,#T_609a9_row4_col4,#T_609a9_row5_col5,#T_609a9_row6_col6,#T_609a9_row7_col7,#T_609a9_row8_col8,#T_609a9_row9_col9,#T_609a9_row10_col10{
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }#T_609a9_row0_col1{
#             background-color:  #aed3e6;
#             color:  #000000;
#         }#T_609a9_row0_col2{
#             background-color:  #a2cde3;
#             color:  #000000;
#         }#T_609a9_row0_col3{
#             background-color:  #e37e64;
#             color:  #000000;
#         }#T_609a9_row0_col4{
#             background-color:  #bddbea;
#             color:  #000000;
#         }#T_609a9_row0_col5,#T_609a9_row8_col2,#T_609a9_row8_col7{
#             background-color:  #dc6e57;
#             color:  #000000;
#         }#T_609a9_row0_col6{
#             background-color:  #6bacd1;
#             color:  #000000;
# ...

# %%
#After dropping TAX we can now coclude that NOX and INDUS are highly correlated,
#and we drop INDUS rather than NOX in respect to MEDV
df= df.drop(["NOX", "B"], axis=1)
df.shape
# Out:
# (506, 9)

# %%
#Correlation matrix, once again
corr_data = df.corr()
corr_data.style.background_gradient(cmap='plasma')
# Out:
# <style  type="text/css" >
# #T_8c040_row0_col0,#T_8c040_row1_col1,#T_8c040_row2_col2,#T_8c040_row3_col3,#T_8c040_row4_col4,#T_8c040_row5_col5,#T_8c040_row6_col6,#T_8c040_row7_col7,#T_8c040_row8_col8{
#             background-color:  #f0f921;
#             color:  #000000;
#         }#T_8c040_row0_col1{
#             background-color:  #eb7556;
#             color:  #000000;
#         }#T_8c040_row0_col2{
#             background-color:  #7b02a8;
#             color:  #f1f1f1;
#         }#T_8c040_row0_col3{
#             background-color:  #e76e5b;
#             color:  #000000;
#         }#T_8c040_row0_col4,#T_8c040_row3_col8{
#             background-color:  #6e00a8;
#             color:  #f1f1f1;
#         }#T_8c040_row0_col5{
#             background-color:  #f89441;
#             color:  #000000;
#         }#T_8c040_row0_col6{
#             background-color:  #d24f71;
#             color:  #000000;
#         }#T_8c040_row0_col7{
#             background-color:  #f07f4f;
# ...

# %% [markdown]
# # Outlier treatment

# %% [markdown]
# # Bring it On!
# - In normalization we rescale numeric values of attributes to the range [1,0].
#
# - Create another dataframe and perform all the above steps followed by normalization of data.
#
# - After model implementation check the effect of normalization on the accuracy of the model
#
# - Instead of heatmap try to create a bar graph to identify collinearity.

# %% [markdown]
# # Expected Outcome
# On completion of this milestone, you should be able to achieve the following:
# - A dataframe being created and a new column having value of target being added to it .
# - Data being observed and understood using different methods
# - Different aspects of data being visualized for a better understanding.
# - Using heatmap features having high corelation with the target label had been identified.

# %% [markdown]
# # Model Implementation
#
# Lets implement the Machine learning models
#
# As we know that this is a regression a problem as we have to predict a continous (non catagorical) value.

# %%
#Importing dataset.
X = df.iloc[:, :-1] #independent variable
y = df.iloc[:, 8] #dependent variable
#We use .iloc for integer-location based indexing for selection by position.

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
X
# Out:
#         CRIM  INDUS     RM   AGE     DIS  RAD  PTRATIO  LSTAT
# 0    0.00632   2.31  6.575  65.2  4.0900  1.0     15.3   4.98
# 1    0.02731   7.07  6.421  78.9  4.9671  2.0     17.8   9.14
# 2    0.02729   7.07  7.185  61.1  4.9671  2.0     17.8   4.03
# 3    0.03237   2.18  6.998  45.8  6.0622  3.0     18.7   2.94
# 4    0.06905   2.18  7.147  54.2  6.0622  3.0     18.7   5.33
# ..       ...    ...    ...   ...     ...  ...      ...    ...
# 501  0.06263  11.93  6.593  69.1  2.4786  1.0     21.0   9.67
# 502  0.04527  11.93  6.120  76.7  2.2875  1.0     21.0   9.08
# 503  0.06076  11.93  6.976  91.0  2.1675  1.0     21.0   5.64
# 504  0.10959  11.93  6.794  89.3  2.3889  1.0     21.0   6.48
# 505  0.04741  11.93  6.030  80.8  2.5050  1.0     21.0   7.88
#
# [506 rows x 8 columns]

# %%
#Next, we use train_test split() from Sklearn to create train and test sets
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Use regression on the training data

from sklearn.linear_model import LinearRegression
linear = LinearRegression()
linear.fit(X_train, Y_train)
Y_pred = linear.predict(X_test)
Y_compare_linear = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
Y_compare_linear.head()
# Out:
#      Actual  Predicted
# 329    22.6  28.561860
# 371    50.0  22.269523
# 219    23.0  25.947354
# 403     8.3  11.058680
# 78     21.2  21.536530

# %%
score=regressor.score(X_test, y_test)*100
print ("R2 score is = ", score )
# Out:
# R2 score is =  51.75206891492069

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.176053919653243

# %%
#Fitting polynomial regression. When we use polynomial regression, we have to fit dataset in Linear Regression first.

polyRegressor = PolynomialFeatures(degree=2,include_bias=False)
X_train_poly = polyRegressor.fit_transform(X_train)
X_test_poly = polyRegressor.fit_transform(X_test)

poly = LinearRegression()
poly.fit(X_train_poly, Y_train)

Y_pred = poly.predict(X_test_poly)
Y_compare_poly = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
Y_compare_poly.head()
# Out:
#      Actual  Predicted
# 329    22.6  27.018862
# 371    50.0  27.416403
# 219    23.0  23.988652
# 403     8.3  11.710584
# 78     21.2  21.082948

# %%
from sklearn.svm import SVR
svr = SVR(kernel= 'rbf')
svr.fit(X_train,Y_train)

Y_pred = svr.predict(X_test)
Y_compare_svr = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})

Y_compare_svr.head()
# Out:
#      Actual  Predicted
# 329    22.6  25.049316
# 371    50.0  17.407133
# 219    23.0  20.890247
# 403     8.3  12.371918
# 78     21.2  22.560663

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=160)
rf.fit(X_train,Y_train)
Y_pred = rf.predict(X_test)
Y_compare_randomforrest = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
Y_compare_randomforrest.head()
# Out:
#      Actual  Predicted
# 329    22.6  24.456250
# 371    50.0  28.453750
# 219    23.0  21.950000
# 403     8.3  12.679375
# 78     21.2  21.244375

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=13)
knn.fit(X_train,Y_train)

Y_pred = knn.predict(X_test)
Y_compare_knn = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})

Y_compare_knn.head()
# Out:
#      Actual  Predicted
# 329    22.6  27.730769
# 371    50.0  23.892308
# 219    23.0  21.984615
# 403     8.3  11.484615
# 78     21.2  22.630769

# %% [markdown]
# # Model Testing
# In this section we will test our prediction with testing data and calculate R2 score to measure model accuracy.
#
# We will also plot the results of the linear regression model.

# %%
score=RF.score(X_test, Y_test)*100
print ("R2 scores is = ", score )
# Out:
# R2 scores is =  74.73692160035328

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))
# Out:
# Mean Absolute Error: 4.584690799396682

# %%
fig, ax = plt.subplots(ncols=5, nrows=1, figsize=(25, 4))
ax = ax.flatten()
Y_compare_linear.head(10).plot(kind='bar', title='Linear Regression', grid=True, ax=ax[0])
Y_compare_poly.head(10).plot(kind='bar', title='Polynomial Regression', grid=True, ax=ax[1])
Y_compare_svr.head(10).plot(kind='bar', title='Support Vector Regression', grid=True, ax=ax[2])
Y_compare_randomforrest.head(10).plot(kind='bar', title='Random Forrest Regression', grid=True, ax=ax[3])
Y_compare_knn.head(10).plot(kind='bar', title='KNN Regression', grid=True, ax=ax[4])
plt.show()

# %%
print('According to R squared scorring method we attained these scores for our machine learning models:')
modelNames = ['Linear', 'Polynomial', 'Support Vector', 'Random Forest', 'K-Nearest Neighbour']
modelRegressors = [linear, poly, svr, rf, knn]
models = pd.DataFrame({'modelNames' : modelNames, 'modelRegressors' : modelRegressors})
counter=0
score=[]
for i in models['modelRegressors']:
  if i is poly:
    accuracy = cvs(i, X_train_poly, Y_train, scoring='r2', cv=5)
    print('Accuracy of %s Regression model is %.2f' %(models.iloc[counter,0],accuracy.mean()))
    score.append(accuracy.mean())
  else:
    accuracy = cvs(i, X_train, Y_train, scoring='r2', cv=5)
    print('Accuracy of %s Regression model is %.2f' %(models.iloc[counter,0],accuracy.mean()))
    score.append(accuracy.mean())
  counter+=1
# Out:
# According to R squared scorring method we attained these scores for our machine learning models:
# Accuracy of Linear Regression model is 0.73
# Accuracy of Polynomial Regression model is 0.84
# Accuracy of Support Vector Regression model is 0.36
# Accuracy of Random Forest Regression model is 0.85
# Accuracy of K-Nearest Neighbour Regression model is 0.60

# %%
pd.DataFrame({'Model Name' : modelNames,'Score' : score}).sort_values(by='Score', ascending=True).plot(x=0, y=1, kind='bar', figsize=(15,5), title='Comparison of R2 scores of differnt models', )
plt.show()

# %% [markdown]
# Thus we can conclude that Random Forest Generator(0.85) and Polynomial Regression(0.84) models are the most efficient for our analysis.
